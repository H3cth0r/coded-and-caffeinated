# %%
from myresources import scrape_agricultural, plot_prices_single_origin
import pandas as pd

# %%
BASE_URL = "https://www.economia-sniim.gob.mx/Nuevo/Consultas/MercadosNacionales/PreciosDeMercado/Agricolas/ResultadosConsultaFechaFrutasYHortalizas.aspx"

PARAMS = {
    "fechaInicio": "01/01/2020",
    "fechaFinal": "10/01/2026",
    "ProductoId": "133",
    "OrigenId": "-1",
    "Origen": "Todos",
    "DestinoId": "-1",
    "Destino": "Todos",
    "PreciosPorId": "2",
    "RegistrosPorPagina": "500",
}

HEADERS = {
    "User-Agent": "Mozilla/5.0",
    "Content-Type": "application/x-www-form-urlencoded",
    "Referer": BASE_URL,
}

# %%
data = scrape_agricultural(BASE_URL, HEADERS, PARAMS)
# Out:
# Scraping page 258 ...

# %%
data.shape
# Out:
# (57223, 8)

# %%
data.head()
# Out:
#         date   presentation     origin  \
# 0 2020-01-02      Kilogramo    Jalisco
# 1 2020-01-02      Kilogramo    Nayarit
# 2 2020-01-02  Caja de 9 kg.  Michoacán
# 3 2020-01-02      Kilogramo    Sinaloa
# 4 2020-01-02      Kilogramo  Michoacán
#
#                                          destination  min_price  max_price  \
# 0  Aguascalientes: Centro Comercial Agropecuario ...      25.00      29.00
# 1                     Nayarit: Nayarabastos de Tepic      49.00      51.00
# 2  Nuevo León: Mercado de Abasto "Estrella" de Sa...      28.89      33.33
# 3                Puebla: Central de Abasto de Puebla      30.00      40.00
# 4          Querétaro: Mercado de Abasto de Querétaro      33.00      38.00
#
#    avg_price notes
# 0       27.0
# 1       50.0
# 2       30.0
# 3       40.0
# 4       35.0

# %%
plot_prices_single_origin(data, "Jalisco",  destinations=None, price_type='avg')

# %%
data.to_csv("avocado.csv")

# %%
print(data.head(20))
# Out:
#          date    presentation      origin  \
# 0  2020-01-02       Kilogramo     Jalisco
# 1  2020-01-02       Kilogramo     Nayarit
# 2  2020-01-02   Caja de 9 kg.   Michoacán
# 3  2020-01-02       Kilogramo     Sinaloa
# 4  2020-01-02       Kilogramo   Michoacán
# 5  2020-01-02  Caja de 10 kg.      México
# 6  2020-01-02       Kilogramo   Michoacán
# 7  2020-01-02   Caja de 9 kg.   Michoacán
# 8  2020-01-02       Kilogramo     Jalisco
# 9  2020-01-02  Caja de 10 kg.   Michoacán
# 10 2020-01-02       Kilogramo   Michoacán
# 11 2020-01-02  Caja de 10 kg.   Michoacán
# 12 2020-01-02  Caja de 10 kg.  Nuevo León
# 13 2020-01-02  Caja de 18 kg.   Michoacán
# 14 2020-01-02  Caja de 10 kg.      Puebla
# 15 2020-01-02   Caja de 9 kg.      Puebla
# 16 2020-01-02       Kilogramo     Nayarit
# 17 2020-01-02  Caja de 16 kg.   Michoacán
# 18 2020-01-02  Caja de 19 kg.   Michoacán
# 19 2020-01-02  Caja de 10 kg.     Jalisco
#
#                                           destination  min_price  max_price  \
# 0   Aguascalientes: Centro Comercial Agropecuario ...      25.00      29.00
# 1                      Nayarit: Nayarabastos de Tepic      49.00      51.00
# 2   Nuevo León: Mercado de Abasto "Estrella" de Sa...      28.89      33.33
# 3                 Puebla: Central de Abasto de Puebla      30.00      40.00
# 4           Querétaro: Mercado de Abasto de Querétaro      33.00      38.00
# 5     Quintana Roo: Mercado de Chetumal, Quintana Roo      35.00      35.00
# 6   San Luis Potosí: Centro de Abasto de San Luis ...      28.50      30.00
# 7   Baja California : Central de Abasto INDIA, Tij...      83.33      83.33
# 8              Sinaloa: Central de Abasto de Culiacán      40.00      40.00
# 9            Sonora: Central de Abasto de Cd. Obregón      54.70      54.70
# 10  Sonora: Mercado de Abasto "Francisco I. Madero...      40.00      45.00
# 11         Tabasco: Central de Abasto de Villahermosa      28.00      32.00
# 12            Tamaulipas: Módulo de Abasto de Reynosa      42.00      45.00
# 13              Veracruz: Central de Abasto de Jalapa      28.89      29.44
# 14          Veracruz: Central de Abasto de Minatitlán      35.00      40.00
# 15                         Veracruz: Mercado Malibrán      33.33      37.78
# 16  Nayarit: Mercado de abasto 'Adolfo López Mateo...      48.00      50.00
# 17              Morelos: Central de Abasto de Cuautla      30.00      35.00
# 18            Michoacán: Mercado de Abasto de Morelia      26.32      28.95
# 19  Baja California Sur: Unión de Comerciantes de ...      78.00      90.00
#
#     avg_price notes
# 0       27.00
# 1       50.00
# 2       30.00
# 3       40.00
# 4       35.00
# 5       35.00
# 6       29.00
# 7       83.33
# 8       40.00
# 9       54.70
# 10      40.00
# 11      30.00
# 12      45.00
# 13      29.17
# 14      37.00
# 15      37.78
# 16      49.00
# 17      30.00
# 18      28.95
# 19      78.00
